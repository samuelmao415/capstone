# %%
import pandas as pd

# %%
top=pd.read_csv("topallproduct_all.csv")

# %%
top.sample(10)
# Out:
#         price                                       product_name
# 8751   $59.50                                 Blouson-Sleeve Top
# 5912   $54.00                Juniors' Off-The-Shoulder Maxin Top
# 1855   $36.00  Women's Los Angeles Dodgers Sleeve Stripe Rela...
# 3818   $54.50         Cotton Tassel-Trim Top, Created for Macy's
# 986    $69.00  Cotton Side-Stripe Ruffled Top, Created for Ma...
# 924    $49.00                            Sleeveless Tie-Neck Top
# 7174   $44.00                                 Ribbed Striped Top
# 5685   $88.00             Plus Size Tie-Sleeve Paisley-Print Top
# 1999   $48.00                  Maternity Dot-Print Boat-Neck Top
# 3246   $35.00                      Juniors' Striped Baby T-Shirt

# %%
dress=pd.read_csv("productnameall.csv")

# %%
dress.sample(10)
# Out:
#          price                                       product_name
# 6137   $129.00       Bell-Sleeve Sheath Dress, Created for Macy's
# 7131   $129.00  R&M Richards Sequined Lace Chiffon Dress and J...
# 1253   $134.00                     Embroidered Scuba Sheath Dress
# 44      $69.00                  Lace Top & Wide-Leg Chiffon Pants
# 4391   $289.00                   Petite Floral-Lace Illusion Gown
# 3005   $128.00                      Strapless Denim Bodycon Dress
# 3021    $79.50  Off-The-Shoulder Floral-Print Dress, Created f...
# 1337   $139.00      V-Neck Printed Lace Dress, Created for Macy's
# 4354   $135.00                  Petite Print Flutter-Sleeve Dress
# 2908    $79.50  French Terry Tab-Sleeve Dress, Created for Macy's

# %%
dress["category"]="dress"

# %%
dress.sample(10)
# Out:
#          price                                       product_name category
# 2994    $89.50  Printed Sleeveless Fit & Flare Dress, Created ...    dress
# 1116   $134.00                    Tiered-Bell-Sleeve Sheath Dress    dress
# 2260   $185.00                  Plus Size Floral-Print Shirtdress    dress
# 2611    $69.00                    Petite Bell-Sleeve Floral Dress    dress
# 805     $69.50  Cotton Striped Chambray-Pocket Dress, Created ...    dress
# 6861   $445.00                    Sequined Fit & Flare Mini Dress    dress
# 1069   $118.00                             Clip-Dot Chiffon Dress    dress
# 4630   $109.00                               Petite Keyhole Dress    dress
# 7519   $279.00                          Beaded Illusion Slit Gown    dress
# 305    $165.00                                Crepe Flounce Dress    dress

# %%
top["category"]="top"

# %%
top
# Out:
#          price                                       product_name category
# 0      $298.00                       Lace Top, Created for Macy's      top
# 1      $228.00                                    Tie-Neck Blouse      top
# 2       $59.50  Embroidered Cold-Shoulder Top, Created for Macy's      top
# 3       $79.00      Ruffled Cold-Shoulder Top, Created for Macy's      top
# 4       $79.00                                Ruffled Plaid Shirt      top
# 5       $49.50                  Cotton Embroidered Cactus T-Shirt      top
# 6       $79.50                    Flutter-Sleeve Tie-Waist Blouse      top
# 7       $49.50                          Printed Toggle-Neck Shell      top
# 8       $79.00                                  Sheer Smocked Top      top
# 9      $119.50                               Embroidered Mesh Top      top
# 10      $79.50  Houndstooth Check Quarter-Zip Top, Created for...      top
# ...

# %%
lis=[top,dress]
all_macys=pd.concat(lis)

# %%
all_macys.shape
# Out:
# (16920, 3)

# %%
all_macys.to_csv("all_macys.csv")
